# %%
# %load_ext watermark
# %watermark -v -n -m -p numpy,sklearn,pandas,openpyxl,seaborn
# Out:
# Python implementation: CPython
# Python version       : 3.10.6
# IPython version      : 8.4.0
#
# numpy   : 1.23.2
# sklearn : 1.1.2
# pandas  : 1.4.3
# openpyxl: 3.0.9
# seaborn : 0.11.2
#
# Compiler    : GCC 10.4.0
# OS          : Linux
# Release     : 5.15.0-46-generic
# Machine     : x86_64
# Processor   : x86_64
# CPU cores   : 8
# Architecture: 64bit

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns
from datetime import datetime

PROJ_ROOT = os.path.abspath(os.path.join(os.pardir))
print(PROJ_ROOT)
# Out:
# /home/fedesss/Dropbox/ML_to_ETa/eta_ml

# %%
df = pd.read_pickle(PROJ_ROOT + '/data/visualization/' + 'prediction.pickle')
df.head()
# Out:
#           0
# 0  1.101329
# 1  1.250227
# 2  1.578569
# 3  1.074756
# 4  0.241235

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
eta = pd.read_pickle(PROJ_ROOT + )
# Out:
#   Input In [10]
#     eta = pd.read_pickle(PROJ_ROOT + )
#                                      ^
# SyntaxError: invalid syntax
